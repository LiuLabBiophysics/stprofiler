# %%
from STProfiler.image.cell_segmentation import *

# %%
import numpy as np
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
from os import getcwd, listdir
from os.path import join, split

# %%
a = np.zeros(10)

# %%
a[0:-0]
# Out:
# array([], dtype=float64)

# %%
curr_path = getcwd()

# %%
test_img_path = join(split(curr_path)[0], 'test', 'test_images')

# %%
test_img_files = listdir(test_img_path)

# %%
test_img = imread(join(test_img_path, test_img_files[1]))

# %%
test_img_files[0]
# Out:
# 'MAX_LCMV-BMS-842098-1L-STAT1-CXCL10-INS-DAPI-1-02-Airyscan Processing-01.tif'

# %%
img_dapi = test_img[:,:,3]

# %%
plt.imshow(img_dapi)

# %%
cp_dir = '/home/changg/Documents/Stereoseq/segment-anything/notebooks/sam_vit_h_4b8939.pth' # please insert your path for SAM vit_h model

# %%
img_dapi.mean()
# Out:
# 1064.7046293663573

# %%
dapi_mask = cell_segmentation(img_dapi, 6000,400000, 
                              scale_factor=2, min_int=1,
                              cp_dir = cp_dir, mask_separation=1)

# %%
fig, axs = plt.subplots(1,3,figsize=(20,9))
axs[0].imshow(img_dapi)
axs[1].imshow(dapi_mask)
axs[2].imshow(dapi_mask!=0)
